# %%
using MTH229
using Plots

# %%
import Pkg; Pkg.add("MTH229")

# %%
Pkg.add("Gadfly")

# %%
f(x) = exp(0.07*x)
t(x) = 0.1x+1
p1=Plots.plot(f, 0, 30)

# %%
f(x) = exp(0.07*x)
t(x) = 0.1x+1
#Plots.scatter(f, -3, 3)
p1=Plots.plot(f, 0, 10)
p2=Plots.plot(t, 0, 10)
Plots.plot(p1,p2; layout = 3)

# %%
f(x) = exp(0.07*x)
t(x) = 0.2x
#Plots.scatter(f, -3, 3)
p1=Plots.plot(f, 10, 20)
p2=Plots.plot(t, 10, 20)
Plots.plot(p1,p2; layout = 3)

# %%
f(x) = exp(0.07*x)
t(x) = 0.4x-4
#Plots.scatter(f, -3, 3)
p1=Plots.plot(f, 20, 30)
p2=Plots.plot(t, 20, 30)
Plots.plot(p1,p2; layout = 3)
